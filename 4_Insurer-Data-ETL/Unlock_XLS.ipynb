# %%
import pandas as pd
import numpy as np
import xlrd
import glob
import os
import csv
import unicodecsv
import win32com.client
xcl = win32com.client.Dispatch("Excel.Application")
xcl.DisplayAlerts = False

# %%
# new idea: unlock xls files by converting then to CSV format.
# todo: 1) check if file is same 2) see how to parse CSV format

print(os.getcwd())
os.chdir('C:/Users/guanz/Desktop/new_input')
FileList = glob.glob('i*.xls*')
#FileList = glob.glob('input.xlsx') #sample_insurer_2013.xlsx')
print(FileList)


# need to take in an index for duplicate filenames
def saveasCSV3(filename, index):
    filename = os.path.abspath(filename)
    print("saveasCSV3 in " + filename + str(index))
    workbook = xcl.Workbooks.Open(filename, False, False, None)
    print("workbook sheet count: " + str(workbook.Sheets.Count))
    output = os.path.join(os.path.dirname(filename), os.path.splitext(os.path.basename(filename))[0])
    end_range = 4
    if workbook.Sheets.Count == 8:
        end_range = 3
    for i in range(1, end_range):
        #csv_filename = output + '_' + str(i) + '.csv'
        csv_filename = output + str(index) + '_' + workbook.Worksheets(i).Name + '.csv'
        workbook.Worksheets(i).SaveAs(csv_filename, 6)
        print("saveasCSV3 out " + csv_filename)
    workbook.Saved = 1
    workbook.Close(False)
#saveasCSV3(r'C:\Users\jli\downloads\Harker Approved Community Service Sites 17-18.xlsx')
#saveasCSV3(r'C:\Users\jli\downloads\s1.xls')


    
index = 0
for File in FileList:
    saveasCSV3(File, index)
    index = index + 1
    #myxls = pd.ExcelFile(File)
    """
    try:
        parse_input(mydf14, mydf15, mydf16, myxls)
    except xlrd.XLRDError:
        errorcount = errorcount + 1
        pass
    """

xcl.Quit()
# Out:
# C:\Users\guanz\Desktop\new_input
# ['input(1).xls', 'input(1).xlsx', 'input(10).xls', 'input(10).xlsx', 'input(100).xls', 'input(100).xlsx', 'input(1000).xls', 'input(1000).xlsx', 'input(1001).xls', 'input(1001).xlsx', 'input(1002).xls', 'input(1002).xlsx', 'input(1003).xls', 'input(1003).xlsx', 'input(1004).xls', 'input(1004).xlsx', 'input(1005).xls', 'input(1005).xlsx', 'input(1006).xls', 'input(1006).xlsx', 'input(1007).xls', 'input(1007).xlsx', 'input(1008).xls', 'input(1008).xlsx', 'input(1009).xls', 'input(1009).xlsx', 'input(101).xls', 'input(101).xlsx', 'input(1010).xls', 'input(1010).xlsx', 'input(1011).xls', 'input(1011).xlsx', 'input(1012).xls', 'input(1012).xlsx', 'input(1013).xls', 'input(1013).xlsx', 'input(1014).xls', 'input(1014).xlsx', 'input(1015).xls', 'input(1015).xlsx', 'input(1016).xls', 'input(1016).xlsx', 'input(1017).xls', 'input(1017).xlsx', 'input(1018).xls', 'input(1018).xlsx', 'input(1019).xls', 'input(1019).xlsx', 'input(102).xls', 'input(102).xlsx', 'input(1020).xls', 'input(1020).xlsx', 'input(1021).xls', 'input(1021).xlsx', 'input(1022).xls', 'input(1022).xlsx', 'input(1023).xls', 'input(1023).xlsx', 'input(1024).xls', 'input(1024).xlsx', 'input(1025).xls', 'input(1025).xlsx', 'input(1026).xls', 'input(1026).xlsx', 'input(1027).xls', 'input(1027).xlsx', 'input(1028).xls', 'input(1028).xlsx', 'input(1029).xls', 'input(1029).xlsx', 'input(103).xls', 'input(103).xlsx', 'input(1030).xls', 'input(1030).xlsx', 'input(1031).xls', 'input(1031).xlsx', 'input(1032).xls', 'input(1032).xlsx', 'input(1033).xls', 'input(1033).xlsx', 'input(1034).xls', 'input(1034).xlsx', 'input(1035).xls', 'input(1035).xlsx', 'input(1036).xls', 'input(1036).xlsx', 'input(1037).xls', 'input(1037).xlsx', 'input(1038).xls', 'input(1038).xlsx', 'input(1039).xls', 'input(1039).xlsx', 'input(104).xls', 'input(104).xlsx', 'input(1040).xls', 'input(1040).xlsx', 'input(1041).xls', 'input(1041).xlsx', 'input(1042).xls', 'input(1042).xlsx', 'input(1043).xls', 'input(1043).xlsx', 'input(1044).xls', 'input(1044).xlsx', 'input(1045).xls', 'input(1045).xlsx', 'input(1046).xls', 'input(1046).xlsx', 'input(1047).xls', 'input(1047).xlsx', 'input(1048).xls', 'input(1048).xlsx', 'input(1049).xls', 'input(1049).xlsx', 'input(105).xls', 'input(105).xlsx', 'input(1050).xls', 'input(1050).xlsx', 'input(1051).xls', 'input(1051).xlsx', 'input(1052).xls', 'input(1052).xlsx', 'input(1053).xls', 'input(1053).xlsx', 'input(1054).xls', 'input(1054).xlsx', 'input(1055).xls', 'input(1055).xlsx', 'input(1056).xls', 'input(1056).xlsx', 'input(1057).xls', 'input(1057).xlsx', 'input(1058).xls', 'input(1058).xlsx', 'input(1059).xls', 'input(1059).xlsx', 'input(106).xls', 'input(106).xlsx', 'input(1060).xls', 'input(1060).xlsx', 'input(1061).xls', 'input(1061).xlsx', 'input(1062).xls', 'input(1062).xlsx', 'input(1063).xls', 'input(1063).xlsx', 'input(1064).xls', 'input(1064).xlsx', 'input(1065).xls', 'input(1065).xlsx', 'input(1066).xls', 'input(1066).xlsx', 'input(1067).xls', 'input(1067).xlsx', 'input(1068).xls', 'input(1068).xlsx', 'input(1069).xls', 'input(1069).xlsx', 'input(107).xls', 'input(107).xlsx', 'input(1070).xls', 'input(1070).xlsx', 'input(1071).xls', 'input(1071).xlsx', 'input(1072).xls', 'input(1072).xlsx', 'input(1073).xls', 'input(1073).xlsx', 'input(1074).xls', 'input(1074).xlsx', 'input(1075).xls', 'input(1075).xlsx', 'input(1076).xls', 'input(1076).xlsx', 'input(1077).xls', 'input(1077).xlsx', 'input(1078).xls', 'input(1078).xlsx', 'input(1079).xls', 'input(1079).xlsx', 'input(108).xls', 'input(108).xlsx', 'input(1080).xls', 'input(1080).xlsx', 'input(1081).xls', 'input(1081).xlsx', 'input(1082).xls', 'input(1082).xlsx', 'input(1083).xls', 'input(1083).xlsx', 'input(1084).xls', 'input(1084).xlsx', 'input(1085).xls', 'input(1085).xlsx', 'input(1086).xls', 'input(1086).xlsx', 'input(1087).xls', 'input(1087).xlsx', 'input(1088).xls', 'input(1088).xlsx', 'input(1089).xls', 'input(1089).xlsx', 'input(109).xls', 'input(109).xlsx', 'input(1090).xls', 'input(1090).xlsx', 'input(1091) ...
# saveasCSV3 in C:\Users\guanz\Desktop\new_input\input(1).xls0
# workbook sheet count: 8
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(1)0_Pt 1 Summary of Data.csv
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(1)0_Pt 2 Premium and Claims.csv
# saveasCSV3 in C:\Users\guanz\Desktop\new_input\input(1).xlsx1
# workbook sheet count: 9
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(1)1_Company Information.csv
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(1)1_Pt 1 Summary of Data.csv
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(1)1_Pt 2 Premium and Claims.csv
# saveasCSV3 in C:\Users\guanz\Desktop\new_input\input(10).xls2
# workbook sheet count: 8
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(10)2_Pt 1 Summary of Data.csv
# saveasCSV3 out C:\Users\guanz\Desktop\new_input\input(10)2_Pt 2 Premium and Claims.csv
# saveasCSV3 in C:\Users\guanz\Desktop\new_input\input(10).xlsx3

# %%
# old scripts
def unprotect_xlsx(filename):
    import win32com.client
    xcl = win32com.client.Dispatch('Excel.Application')
    pw_str = '12345'
    wb = xcl.workbooks.open(filename)
    wb.Unprotect(pw_str)
    wb.UnprotectSharing(pw_str)
    xcl.DisplayAlerts = False
    wb.Save()
    print("wb.Save")
    xcl.Quit()
#unprotect_xlsx('C:\\Users\\guanz\\Desktop\\new_input\\input(1).xlsx')

def Remove_password_xlsx(filename, pw_str):
    import win32com.client
    xcl = win32com.client.Dispatch("Excel.Application")
    wb = xcl.Workbooks.Open(filename, False, False, None, pw_str)
    xcl.DisplayAlerts = True
    #wb.SaveAs(filename, None, '', '')
    #wb.Save()
    #wb.SaveAs(r"c:/users/jli/downloads/test.csv", FileFormat="6")
    print(xcl.parse(0))
    xcl.Quit()
#Remove_password_xlsx(r'C:/Users/jli/downloads/sample_insurer_2013.xlsx', '12345')

def saveasCSV(filename, output):
    #import win32com.client
    #xcl = win32com.client.Dispatch("Excel.Application")
    wb = xcl.Workbooks.Open(filename, False, False, None)
    xcl.DisplayAlerts = False
    #wb.SaveAs(filename, None, '', '')
    #wb.Save()
    wb.SaveAs(output, FileFormat="6")
    wb.Close(False)
    print("Produced ") + output
    #xcl.Quit()
#saveasCSV(r'C:/Users/jli/downloads/s1.xls', r'C:\Users\jli\downloads\s1.csv')

def saveasCSV1(filename):
    #import win32com.client
    #xcl = win32com.client.Dispatch("Excel.Application")
    filename = os.path.abspath(filename)
    print("saveasCSV1 in " + filename)
    wb = xcl.Workbooks.Open(filename, False, False, None)
    output = os.path.join(os.path.dirname(filename), os.path.splitext(os.path.basename(filename))[0]) + ".csv"
    wb.SaveAs(output, FileFormat="6")
    wb.Close(False)
    print("saveasCSV1 out " + output)
    #xcl.Quit()
#saveasCSV1(r'C:\Users\jli\downloads\s1.xls')

#non-encrypted: creates csv per worksheet
def saveasCSV2(filename):
    filename = os.path.abspath(filename)
    print("saveasCSV2 in " + filename)
    workbook = xlrd.open_workbook(filename) #Workbook is encrypted
    print(workbook.nsheets)
    print(workbook.sheet_names())
    all_worksheets = workbook.sheet_names()
    output = os.path.join(os.path.dirname(filename), os.path.splitext(os.path.basename(filename))[0])
    for worksheet_name in all_worksheets:
        worksheet = workbook.sheet_by_name(worksheet_name)
        if worksheet.nrows == 0: 
            continue
        csv_filename = output + '=' + worksheet_name + '.csv'
        fh = open(csv_filename, 'wb')
        csv_out = unicodecsv.writer(fh, encoding='utf-8')

        for row_number in range (worksheet.nrows):
            csv_out.writerow(worksheet.row_values(row_number))

        fh.close()
#saveasCSV2(r'C:\Users\jli\downloads\s1.xls')


def opensave(filename):
    print("opensave")
    print(filename)
    import win32com.client
    xcl = win32com.client.Dispatch("Excel.Application")
    wb = xcl.Workbooks.Open(filename, False, False, None)
    xcl.DisplayAlerts = True
    wb.SaveCopyAs(r'c:\users\jli\desktop\test.xls')
    wb.Close()
    #print(xcl.parse(0))
    xcl.Quit()
#opensave(r'C:/Users/jli/downloads/input(1001)2.xlsx')

# %%
def parse_input(df14, df15, df16, xls):
    
    sheet0 = xls.parse(0)
    
    # 2014, 2015, and 2016 format
    if sheet0.iloc[2,0] == 'Company Name:': # should say "Company Name:"
        # hios id is 11C (9,1) in sheet 0
        # company name 4C (2,1) is in sheet 0
        # company state is 12C (10,1) in sheet 0
        # print(sheet0.iloc[9,1]) hios id
        # print(sheet0.iloc[2,1]) company name
        # print(sheet0.iloc[10,1]) company state 
        # print(sheet0.iloc[16,1]) reporting year
        reporting_year = sheet0.iloc[16,1]
        if reporting_year == 'No':
            reporting_year = sheet0.iloc[17,1]
        
        # individual member months is in section 1.7 59E (57,3) in sheet 1
        # small group member months is in section 1.7 59K (57,9) in sheet 1
        
        sheet1 = xls.parse(1)
        # print(sheet1.iloc[57,3]) individual member months
        # print(sheet1.iloc[57,9]) small group member months

        # reinsurance is in section 1.9 which is 15E in sheet 2
        # individual risk adjustment is in section 1.10 which is 16E in sheet 2
        # small group risk adjustment is in section 1.10 which is 16K in sheet 2
        sheet2 = xls.parse(2)
        # print(sheet2.iloc[13,3]) reinsurance
        # print(sheet2.iloc[14,3]) individual risk adjustment
        # print(sheet2.iloc[14,9]) small group risk adjustment

        if reporting_year == '2014':
            df14.loc[df14.shape[0]] = [sheet0.iloc[9,1], # hios id
                                   sheet0.iloc[2,1],  # company name
                                   sheet0.iloc[10,1], # company state
                                   sheet1.iloc[57,3], # individual member months
                                   sheet1.iloc[57,9], # small group member months
                                   sheet2.iloc[13,3], # reinsurance
                                   sheet2.iloc[14,3], # individual risk adjustment
                                   sheet2.iloc[14,9]] # small group risk adjustment
        elif reporting_year == '2015':
            df15.loc[df15.shape[0]] = [sheet0.iloc[9,1], # hios id
                                   sheet0.iloc[2,1],  # company name
                                   sheet0.iloc[10,1], # company state
                                   sheet1.iloc[57,3], # individual member months
                                   sheet1.iloc[57,9], # small group member months
                                   sheet2.iloc[13,3], # reinsurance
                                   sheet2.iloc[14,3], # individual risk adjustment
                                   sheet2.iloc[14,9]] # small group risk adjustment
        elif reporting_year == '2016':
            df16.loc[df16.shape[0]] = [sheet0.iloc[9,1], # hios id
                                   sheet0.iloc[2,1],  # company name
                                   sheet0.iloc[10,1], # company state
                                   sheet1.iloc[57,3], # individual member months
                                   sheet1.iloc[57,9], # small group member months
                                   sheet2.iloc[13,3], # reinsurance
                                   sheet2.iloc[14,3], # individual risk adjustment
                                   sheet2.iloc[14,9]] # small group risk adjustment
    # else: # 2011, 2012, 2013 format
        #print(sheet0.iloc[9,3]) # hios id
        #print(sheet0.iloc[4,2]) # company name
        #print(sheet0.iloc[8,7]) # company state
        #print(sheet0.iloc[79,8]) # individual member months
        #print(sheet0.iloc[79,13]) # small group member months
        # reinsurance, risk adjustment missing?
    
    #print("parse_input defined")

# %%
# create the dataframe to run actual script

errorcount = 0

mydf14 = pd.DataFrame(columns=('HIOS_ID', 'COMPANY_NAME', 'STATE', 
                        'IND_MEMBER_MONTHS', 'SG_MEMBER_MONTHS',
                       'REINSURANCE', 'IND_RISK_ADJ', 'SG_RISK_ADJ'))
mydf15 = pd.DataFrame(columns=('HIOS_ID', 'COMPANY_NAME', 'STATE', 
                        'IND_MEMBER_MONTHS', 'SG_MEMBER_MONTHS',
                       'REINSURANCE', 'IND_RISK_ADJ', 'SG_RISK_ADJ'))
mydf16 = pd.DataFrame(columns=('HIOS_ID', 'COMPANY_NAME', 'STATE', 
                        'IND_MEMBER_MONTHS', 'SG_MEMBER_MONTHS',
                       'REINSURANCE', 'IND_RISK_ADJ', 'SG_RISK_ADJ'))

print("There were " + str(errorcount) + " encrypted files.")
print(mydf14)
print(mydf15)
print(mydf16)
# Out:
# There were 0 encrypted files.
# Empty DataFrame
# Columns: [HIOS_ID, COMPANY_NAME, STATE, IND_MEMBER_MONTHS, SG_MEMBER_MONTHS, REINSURANCE, IND_RISK_ADJ, SG_RISK_ADJ]
# Index: []
# Empty DataFrame
# Columns: [HIOS_ID, COMPANY_NAME, STATE, IND_MEMBER_MONTHS, SG_MEMBER_MONTHS, REINSURANCE, IND_RISK_ADJ, SG_RISK_ADJ]
# Index: []
# Empty DataFrame
# Columns: [HIOS_ID, COMPANY_NAME, STATE, IND_MEMBER_MONTHS, SG_MEMBER_MONTHS, REINSURANCE, IND_RISK_ADJ, SG_RISK_ADJ]
# Index: []
