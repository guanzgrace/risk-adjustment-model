# %%
# to do:
# - Delete null columns
# - Delete duplicate rows
# - Add PDF data to the file
# - Basic statistical analysis (min, max, range, etc., basic what the data means, correlation)
import pandas as pd

# %%
data_2014 = pd.read_csv("input/2014-all.csv", encoding = "ISO-8859-1", low_memory=False)

# %%
data_2014.head()
# Out:
#    Unnamed: 0                           CompanyName: GroupAffiliation:  \
# 0           0              Cariten Health Plan, Inc.        HUMANA GRP
# 1           1              Cariten Health Plan, Inc.        HUMANA GRP
# 2           2             Emphesys Insurance Company        HUMANA GRP
# 3           3             Emphesys Insurance Company        HUMANA GRP
# 4           4  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    621579044          95754.0           119.0           95754.0
# 1    621579044          95754.0           119.0           95754.0
# 2    310935772          88595.0           119.0           88595.0
# 3    310935772          88595.0           119.0           88595.0
# 4    371326199          60052.0           119.0           60052.0
#
#   DBA/MarketingName:  HIOSIssuerID: BusinessintheStateof:  \
# 0             Humana            NaN           Grand Total
# ...

# %%
data_2014 = data_2014.dropna(axis=1,how='all') # drop columns that are entirely null

# %%
data_2014.head()
# Out:
#    Unnamed: 0                           CompanyName: GroupAffiliation:  \
# 0           0              Cariten Health Plan, Inc.        HUMANA GRP
# 1           1              Cariten Health Plan, Inc.        HUMANA GRP
# 2           2             Emphesys Insurance Company        HUMANA GRP
# 3           3             Emphesys Insurance Company        HUMANA GRP
# 4           4  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    621579044          95754.0           119.0           95754.0
# 1    621579044          95754.0           119.0           95754.0
# 2    310935772          88595.0           119.0           88595.0
# 3    310935772          88595.0           119.0           88595.0
# 4    371326199          60052.0           119.0           60052.0
#
#   DBA/MarketingName:  HIOSIssuerID: BusinessintheStateof:  \
# 0             Humana            NaN           Grand Total
# ...

# %%
data_2014.tail()
# Out:
#       Unnamed: 0                                       CompanyName:  \
# 5054        5054                   UnitedHealthcare of Oregon, Inc.
# 5055        5055                                           SHA, LLC
# 5056        5056                                           SHA, LLC
# 5057        5057  Wisconsin Physicians Services Insurance Corpor...
# 5058        5058  Wisconsin Physicians Services Insurance Corpor...
#
#                       GroupAffiliation:  FederalEIN:  A.M.BestNumber:  \
# 5054                   UNITEDHEALTH GRP    930938819          68707.0
# 5055                      Firstcare Grp    752569094          60114.0
# 5056                      Firstcare Grp    752569094          60114.0
# 5057  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
# 5058  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
#
#       NAICGroupCode:  NAICCompanyCode:                DBA/MarketingName:  \
# ...

# %%
del data_2014["Unnamed: 0"]

# %%
data_2014 = data_2014.drop_duplicates(subset=None, keep='first', inplace=False) # delete duplicate rows

# %%
data_2014.head()
# Out:
#                             CompanyName: GroupAffiliation:  FederalEIN:  \
# 0              Cariten Health Plan, Inc.        HUMANA GRP    621579044
# 1              Cariten Health Plan, Inc.        HUMANA GRP    621579044
# 2             Emphesys Insurance Company        HUMANA GRP    310935772
# 3             Emphesys Insurance Company        HUMANA GRP    310935772
# 4  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP    371326199
#
#    A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode: DBA/MarketingName:  \
# 0          95754.0           119.0           95754.0             Humana
# 1          95754.0           119.0           95754.0             Humana
# 2          88595.0           119.0           88595.0             Humana
# 3          88595.0           119.0           88595.0             Humana
# 4          60052.0           119.0           60052.0             Humana
#
#    HIOSIssuerID: BusinessintheStateof: DomiciliaryState:  \
# ...

# %%
data_2014.tail()
# Out:
#                                            CompanyName:  \
# 5054                   UnitedHealthcare of Oregon, Inc.
# 5055                                           SHA, LLC
# 5056                                           SHA, LLC
# 5057  Wisconsin Physicians Services Insurance Corpor...
# 5058  Wisconsin Physicians Services Insurance Corpor...
#
#                       GroupAffiliation:  FederalEIN:  A.M.BestNumber:  \
# 5054                   UNITEDHEALTH GRP    930938819          68707.0
# 5055                      Firstcare Grp    752569094          60114.0
# 5056                      Firstcare Grp    752569094          60114.0
# 5057  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
# 5058  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
#
#       NAICGroupCode:  NAICCompanyCode:                DBA/MarketingName:  \
# 5054           707.0           95893.0  UnitedHealthcare of Oregon, Inc.
# ...

# %%
data_2014.to_csv("2014_all_1.csv")

# %%
data_2014 = data_2014[data_2014["BusinessintheStateof:"] != "Grand Total"]

# %%
data_2014.head()
# Out:
#                             CompanyName: GroupAffiliation:  FederalEIN:  \
# 1              Cariten Health Plan, Inc.        HUMANA GRP    621579044
# 2             Emphesys Insurance Company        HUMANA GRP    310935772
# 5  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP    371326199
# 6  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP    371326199
# 7  Humana Benefit Plan of Illinois, Inc.        HUMANA GRP    371326199
#
#    A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode: DBA/MarketingName:  \
# 1          95754.0           119.0           95754.0             Humana
# 2          88595.0           119.0           88595.0             Humana
# 5          60052.0           119.0           60052.0             Humana
# 6          60052.0           119.0           60052.0             Humana
# 7          60052.0           119.0           60052.0             Humana
#
#    HIOSIssuerID: BusinessintheStateof: DomiciliaryState:  \
# ...

# %%
data_2014.tail()
# Out:
#                                            CompanyName:  \
# 5050                     CDPHP Universal Benefits, Inc.
# 5051                 UnitedHealthcare of Arkansas, Inc.
# 5054                   UnitedHealthcare of Oregon, Inc.
# 5056                                           SHA, LLC
# 5058  Wisconsin Physicians Services Insurance Corpor...
#
#                       GroupAffiliation:  FederalEIN:  A.M.BestNumber:  \
# 5050                              CDPHP    161520935          64596.0
# 5051                   UNITEDHEALTH GRP    631036819          68914.0
# 5054                   UNITEDHEALTH GRP    930938819          68707.0
# 5056                      Firstcare Grp    752569094          60114.0
# 5058  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
#
#       NAICGroupCode:  NAICCompanyCode:                  DBA/MarketingName:  \
# 5050          4708.0           47027.0      CDPHP Universal Benefits, Inc.
# ...

# %%
data_2014.to_csv("2014_all_2.csv")

# %%
pdf_data_2014 = pd.read_csv("input/2014-pdf-all.csv")

# %%
pdf_data_2014 = pdf_data_2014.rename(columns={'HIOS ID': 'HIOSIssuerID:',
        'HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)': 
    '1.10FederalRiskAdjustmentProgramnetpaymentsexpectedfromHHS/(chargespayabletoHHS)(asindicatedbyHHSasof6/30)2HealthInsuranceINDIVIDUALTotalasof3/31/15'})

# %%
pdf_data_2014.head()
# Out:
#    Unnamed: 0  HIOSIssuerID:      HIOS INPUTTED INSURANCE COMPANY NAME STATE  \
# 0           0          11082              Aetna Life Insurance Company    AK
# 1           1          62637         John Alden Life Insurance Company    AK
# 2           2          73836                    Moda Health Plan, Inc.    AK
# 3           3          38344  Premera Blue Cross Blue Shield of Alaska    AK
# 4           4          38596                    Time Insurance Company    AK
#
#   REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)  \
# 0                                  $120,363.61
# 1                                          N/E
# 2                               $13,102,419.34
# 3                               $19,984,669.96
# 4                                $1,558,728.91
#
#   1.10FederalRiskAdjustmentProgramnetpaymentsexpectedfromHHS/(chargespayabletoHHS)(asindicatedbyHHSasof6/30)2HealthInsuranceINDIVIDUALTotalasof3/31/15  \
# 0                                       $(52,362.57)
# ...
