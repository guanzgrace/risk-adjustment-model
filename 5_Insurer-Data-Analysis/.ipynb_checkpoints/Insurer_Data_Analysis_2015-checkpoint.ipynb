# %%
# to do:
# - Delete null columns
# - Delete duplicate rows
# - Add PDF data to the file
# - Basic statistical analysis (min, max, range, etc., basic what the data means, correlation)
import pandas as pd

# %%
data_2015 = pd.read_csv("input/2015-all.csv", encoding = "ISO-8859-1", low_memory=False)

# %%
data_2015.head()
# Out:
#    Unnamed: 0                                CompanyName: GroupAffiliation:  \
# 0           0                                 AvMed, Inc.               NaN
# 1           1                                 AvMed, Inc.               NaN
# 2           2  Blue Cross and Blue Shield of Kansas, Inc.    BCBS of KS GRP
# 3           3  Blue Cross and Blue Shield of Kansas, Inc.    BCBS of KS GRP
# 4           4            UnitedHealthcare of Oregon, Inc.  UNITEDHEALTH GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    592742907          64074.0             NaN           95263.0
# 1    592742907          64074.0             NaN           95263.0
# 2    480952857          60070.0           430.0           70729.0
# 3    480952857          60070.0           430.0           70729.0
# 4    930938819          68707.0           707.0           95893.0
#
#                            DBA/MarketingName:  HIOSIssuerID:  \
# ...

# %%
data_2015 = data_2015.dropna(axis=1,how='all') # drop columns that are entirely null

# %%
data_2015.head()
# Out:
#    Unnamed: 0                                CompanyName: GroupAffiliation:  \
# 0           0                                 AvMed, Inc.               NaN
# 1           1                                 AvMed, Inc.               NaN
# 2           2  Blue Cross and Blue Shield of Kansas, Inc.    BCBS of KS GRP
# 3           3  Blue Cross and Blue Shield of Kansas, Inc.    BCBS of KS GRP
# 4           4            UnitedHealthcare of Oregon, Inc.  UNITEDHEALTH GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    592742907          64074.0             NaN           95263.0
# 1    592742907          64074.0             NaN           95263.0
# 2    480952857          60070.0           430.0           70729.0
# 3    480952857          60070.0           430.0           70729.0
# 4    930938819          68707.0           707.0           95893.0
#
#                            DBA/MarketingName:  HIOSIssuerID:  \
# ...

# %%
data_2015.tail()
# Out:
#       Unnamed: 0                                       CompanyName:  \
# 4201        4201                        Unimerica Insurance Company
# 4202        4202                        Unimerica Insurance Company
# 4203        4203  Wisconsin Physicians Services Insurance Corpor...
# 4204        4204  Wisconsin Physicians Services Insurance Corpor...
# 4205        4205  Wisconsin Physicians Services Insurance Corpor...
#
#                       GroupAffiliation:  FederalEIN:  A.M.BestNumber:  \
# 4201                   UNITEDHEALTH GRP    521996029           9065.0
# 4202                   UNITEDHEALTH GRP    521996029           9065.0
# 4203  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
# 4204  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
# 4205  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
#
#       NAICGroupCode:  NAICCompanyCode:           DBA/MarketingName:  \
# ...

# %%
data_2015 = data_2015[data_2015["BusinessintheStateof:"] != "Grand Total"]

# %%
data_2015.head()
# Out:
#    Unnamed: 0                                CompanyName:  \
# 0           0                                 AvMed, Inc.
# 3           3  Blue Cross and Blue Shield of Kansas, Inc.
# 5           5            UnitedHealthcare of Oregon, Inc.
# 7           7                TRH Health Insurance Company
# 9           9            Horizon Healthcare of New Jersey
#
#               GroupAffiliation:  FederalEIN:  A.M.BestNumber:  NAICGroupCode:  \
# 0                           NaN    592742907          64074.0             NaN
# 3                BCBS of KS GRP    480952857          60070.0           430.0
# 5              UNITEDHEALTH GRP    930938819          68707.0           707.0
# 7  TRH Health Insurance Company    621779831              NaN          4677.0
# 9                BCBS OF NJ GRP    222651245          64022.0          1202.0
#
#    NAICCompanyCode:                          DBA/MarketingName:  \
# 0           95263.0                          AvMed Health Plans
# ...

# %%
del data_2015["Unnamed: 0"]

# %%
data_2015 = data_2015.drop_duplicates(subset='HIOSIssuerID:', keep='first', inplace=False) # delete duplicate rows

# %%
data_2015.head()
# Out:
#                                  CompanyName:             GroupAffiliation:  \
# 0                                 AvMed, Inc.                           NaN
# 3  Blue Cross and Blue Shield of Kansas, Inc.                BCBS of KS GRP
# 5            UnitedHealthcare of Oregon, Inc.              UNITEDHEALTH GRP
# 7                TRH Health Insurance Company  TRH Health Insurance Company
# 9            Horizon Healthcare of New Jersey                BCBS OF NJ GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    592742907          64074.0             NaN           95263.0
# 3    480952857          60070.0           430.0           70729.0
# 5    930938819          68707.0           707.0           95893.0
# 7    621779831              NaN          4677.0           89005.0
# 9    222651245          64022.0          1202.0           95529.0
#
#                            DBA/MarketingName:  HIOSIssuerID:  \
# ...

# %%
data_2015.to_csv("2015_all_1.csv")

# %%
data_2015.tail()
# Out:
#                                            CompanyName:  \
# 4200                        Unimerica Insurance Company
# 4201                        Unimerica Insurance Company
# 4202                        Unimerica Insurance Company
# 4204  Wisconsin Physicians Services Insurance Corpor...
# 4205  Wisconsin Physicians Services Insurance Corpor...
#
#                       GroupAffiliation:  FederalEIN:  A.M.BestNumber:  \
# 4200                   UNITEDHEALTH GRP    521996029           9065.0
# 4201                   UNITEDHEALTH GRP    521996029           9065.0
# 4202                   UNITEDHEALTH GRP    521996029           9065.0
# 4204  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
# 4205  WISCONSIN PHYSICIANS SERV INS GRP    391268299              NaN
#
#       NAICGroupCode:  NAICCompanyCode:           DBA/MarketingName:  \
# 4200           707.0           91529.0  Unimerica Insurance Company
# ...

# %%
data_2015.head()
# Out:
#                                  CompanyName:             GroupAffiliation:  \
# 0                                 AvMed, Inc.                           NaN
# 3  Blue Cross and Blue Shield of Kansas, Inc.                BCBS of KS GRP
# 5            UnitedHealthcare of Oregon, Inc.              UNITEDHEALTH GRP
# 7                TRH Health Insurance Company  TRH Health Insurance Company
# 9            Horizon Healthcare of New Jersey                BCBS OF NJ GRP
#
#    FederalEIN:  A.M.BestNumber:  NAICGroupCode:  NAICCompanyCode:  \
# 0    592742907          64074.0             NaN           95263.0
# 3    480952857          60070.0           430.0           70729.0
# 5    930938819          68707.0           707.0           95893.0
# 7    621779831              NaN          4677.0           89005.0
# 9    222651245          64022.0          1202.0           95529.0
#
#                            DBA/MarketingName:  HIOSIssuerID:  \
# ...

# %%
pdf_data_2015 = pd.read_csv("input/2015-pdf-all.csv")

# %%
pdf_data_2015 = pdf_data_2015.rename(columns={'HIOS ID': 'HIOSIssuerID:'})

# %%
pdf_data_2015.head()
# Out:
#    Unnamed: 0  HIOSIssuerID:      HIOS INPUTTED INSURANCE COMPANY NAME STATE  \
# 0           0          11082              Aetna Life Insurance Company    AK
# 1           1          38344  Premera Blue Cross Blue Shield of Alaska    AK
# 2           2          38596                    Time Insurance Company    AK
# 3           3          62637         John Alden Life Insurance Company    AK
# 4           4          73836                    Moda Health Plan, Inc.    AK
#
#   REINSURANCE PAYMENT AMOUNT (OR NOT ELIGIBLE)  \
# 0                                        $0.00
# 1                               $14,655,165.10
# 2                                $1,167,367.38
# 3                                          N/E
# 4                               $26,305,543.39
#
#   HHS RISK ADJUSTMENT TRANSFER AMOUNT (INDIVIDUAL MARKET, INCLUDING CATASTROPHIC)  \
# 0                                       $(34,550.55)
# 1                                     $12,358,455.76
# ...

# %%
s1 = pd.merge(data_2015, pdf_data_2015, how='left', on=['HIOSIssuerID:'])

# %%
print(s1[s1["HHS RISK ADJUSTMENT TRANSFERS AMOUNT (SMALL GROUP MARKET)"].notnull()])
# Out:
#                                            CompanyName:  \
# 0                                           AvMed, Inc.
# 1            Blue Cross and Blue Shield of Kansas, Inc.
# 4                      Horizon Healthcare of New Jersey
# 5                     Horizon Healthcare Services, Inc.
# 6           BlueCross BlueShield Kansas Solutions, Inc.
# 7               Boston Medical Center Health Plan, Inc.
# 8             BLUE CROSS AND BLUE SHIELD OF KANSAS CITY
# 9             BLUE CROSS AND BLUE SHIELD OF KANSAS CITY
# 11                        California Physicians Service
# 14                                  HMO Louisiana, Inc.
# 15       Louisiana Health Service and Indemnity Company
# 17                            Group Health Options, Inc
# 19               Freelancers Health Service Corporation
# 20                     Denver Health Medical Plan, Inc.
# 21                Physicians Plus Insurance Corporation
# 22                      Optima Health Insurance Company
# ...

# %%
s1.to_csv("2015_final.csv")
