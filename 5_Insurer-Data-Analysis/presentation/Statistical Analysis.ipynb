# %%
# simple statistical analysis
# Author: Grace Guan 12/12/17

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# import the datasets
df14 = pd.read_csv("2014_final_condensed.csv")
df15 = pd.read_csv("2015_final_condensed.csv")

# remove errors
df14 = df14.replace(['#DIV/0!', '#VALUE!', 'N/E', '$-', 'N/A_MA_Issuer', 'N/A_DefaultCharge'], np.nan)
df15 = df15.replace(['#DIV/0!', '#VALUE!', 'N/E', '$-', 'N/A_MA_Issuer', 'N/A_DefaultCharge'], np.nan)

# %%
numeric_cols = ['MM Individual',
 'MM Small Group',
 'Expected Reinsurance',
 'Expected Risk Adjustment Individual',
 'Expected Risk Adjustment Small Group',
 'Actual Reinsurance',
 'Actual Risk Adjustment Individual',
 'Actual Risk Adjustment Small Group',
 'Expected Reinsurance Per Member Month',
 'Actual Reinsurance Per Member Month',
 'Expected Risk Adjustment Per Member Month Individual',
 'Actual Risk Adjustment Per Member Month Individual',
 'Expected Risk Adjustment Per Member Month Small Group',
 'Actual Risk Adjustment Per Member Month Small Group',
 'Difference in Reinsurance Per Member Month',
 'Difference in Risk Adjustment Individual Per Member Month',
 'Difference in Risk Adjustment Small Group Per Member Month']

# suppress output for table in next cell

#print("Column\tMean2014\tMean2015\tMedian2014\tMedian2015\tStd2014\tStd2015" + 
#     "\tMin2014\tMin2015\tMax2014\tMax2015\tSum2014\tSum2015")

for col in numeric_cols:
    df14[col] = pd.to_numeric(df14[col])
    df15[col] = pd.to_numeric(df15[col])
    #print(col + "\t" + str(df14[col].mean()) + "\t" + str(df15[col].mean()) +
    #     "\t" + str(df14[col].median()) + "\t" + str(df15[col].median()) + 
    #     "\t" + str(df14[col].std()) + "\t" + str(df15[col].std()) + 
    #     "\t" + str(df14[col].min()) + "\t" + str(df15[col].min()) +
    #     "\t" + str(df14[col].max()) + "\t" + str(df15[col].max()) +
    #     "\t" + str(df14[col].sum()) + "\t" + str(df15[col].sum()))

# %% [markdown]
# ## Statistics
#
# | Column                                                     | Mean2014            | Mean2015             | Median2014 | Median2015 | Std2014            | Std2015            | Min2014       | Min2015       | Max2014      | Max2015      | Sum2014             | Sum2015             |
# |------------------------------------------------------------|---------------------|----------------------|------------|------------|--------------------|--------------------|---------------|---------------|--------------|--------------|---------------------|---------------------|
# | MM Individual                                              | 81228.65311533363   | 110820.83463745436   | 216.0      | 296.0      | 438214.3219318751  | 546530.9985007626  | 0.0           | 0.0           | 9694097.0    | 11485974.0   | 183820442.0         | 212443540.0         |
# | MM Small Group                                             | 125045.95792880259  | 137340.75309597523   | 561.0      | 894.0      | 494421.59717000637 | 504339.6410029636  | 0.0           | 0.0           | 8623746.0    | 8594675.0    | 193196005.0         | 177444253.0         |
# | Expected Reinsurance                                       | 4866935.3453283785  | 5938043.616373677    | 0.0        | 0.0        | 26312095.86629803  | 28084490.887964003 | -265035.1     | 0.0           | 549029026.7  | 636679179.0  | 7855233647.3600025  | 7850093660.846001   |
# | Difference in Risk Adjustment Individual Per Member Month  | 0.03410309278350507 | 1.257340909090909    | 0.0        | 0.0        | 9.177297890137796  | 21.13951268688122  | -181.79       | -127.21       | 122.63       | 641.58       | 49.61999999999988   | 1659.6899999999998  |
# | Difference in Risk Adjustment Small Group Per Member Month | -0.4179085714285715 | -0.37247043363994764 | 0.0        | 0.0        | 14.719777425341258 | 16.884387749586935 | -392.79       | -333.48       | 114.1        | 161.92       | -365.6700000000001  | -283.45000000000016 |

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df14["HIOS ID"], df14["Expected Reinsurance Per Member Month"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df14["HIOS ID"], df14["Actual Reinsurance Per Member Month"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df14["HIOS ID"], df14["Difference in Reinsurance Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-100,1000])
ax2.set_ylim([-100,1000])
ax3.set_ylim([-100,1000])
plt.show()

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df15["HIOS ID"], df15["Expected Reinsurance Per Member Month"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df15["HIOS ID"], df15["Actual Reinsurance Per Member Month"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df15["HIOS ID"], df15["Difference in Reinsurance Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-100,1000])
ax2.set_ylim([-100,1000])
ax3.set_ylim([-100,1000])
plt.show()

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df14["HIOS ID"], df14["Expected Risk Adjustment Per Member Month Individual"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df14["HIOS ID"], df14["Actual Risk Adjustment Per Member Month Individual"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df14["HIOS ID"], df14["Difference in Risk Adjustment Individual Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-500,500])
ax2.set_ylim([-500,500])
ax3.set_ylim([-500,500])
plt.show()

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df15["HIOS ID"], df15["Expected Risk Adjustment Per Member Month Individual"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df15["HIOS ID"], df15["Actual Risk Adjustment Per Member Month Individual"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df15["HIOS ID"], df15["Difference in Risk Adjustment Individual Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-500,500])
ax2.set_ylim([-500,500])
ax3.set_ylim([-500,500])
plt.show()

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df15["HIOS ID"], df15["Expected Risk Adjustment Per Member Month Small Group"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df15["HIOS ID"], df15["Actual Risk Adjustment Per Member Month Small Group"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df15["HIOS ID"], df15["Difference in Risk Adjustment Small Group Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-500,500])
ax2.set_ylim([-500,500])
ax3.set_ylim([-500,500])
plt.show()

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax1 = plt.subplots(figsize=(14, 14))
ax1.set_title('Expected (Red) vs. Actual (Blue) Reinsurance Per Member Month \
with Expected-Actual Difference (Green) for 2014 BY')
ax2 = ax1.twinx()
ax3 = ax1.twinx()

ax1.plot(df14["HIOS ID"], df14["Expected Risk Adjustment Per Member Month Small Group"], '+', color='r')
ax1.set_xlabel('HIOS ID')
ax1.set_ylabel('expected reinsurance')

ax2.plot(df14["HIOS ID"], df14["Actual Risk Adjustment Per Member Month Small Group"], 'x', color='b')
ax2.set_ylabel('actual reinsurance')

ax3.plot(df14["HIOS ID"], df14["Difference in Risk Adjustment Small Group Per Member Month"], 'o', color='g')

# Change color of each axis
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
color_y_axis(ax3, 'b') # overlapping axis is also blue

ax1.set_ylim([-500,500])
ax2.set_ylim([-500,500])
ax3.set_ylim([-500,500])
plt.show()

# %%
# does a bad prediction one year lead to a better prediction the next year?

combined = pd.merge(df14, df15, on='HIOS ID')
